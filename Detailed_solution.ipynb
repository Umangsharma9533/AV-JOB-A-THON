# %%
import pandas as pd

# %%
df_raw=pd.read_csv('train_s3TEQDk.csv')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245725 entries, 0 to 245724
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   245725 non-null  object
#  1   Gender               245725 non-null  object
#  2   Age                  245725 non-null  int64
#  3   Region_Code          245725 non-null  object
#  4   Occupation           245725 non-null  object
#  5   Channel_Code         245725 non-null  object
#  6   Vintage              245725 non-null  int64
#  7   Credit_Product       216400 non-null  object
#  8   Avg_Account_Balance  245725 non-null  int64
#  9   Is_Active            245725 non-null  object
#  10  Is_Lead              245725 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 20.6+ MB

# %%
df=df_raw.dropna(axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216400 entries, 0 to 245724
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   216400 non-null  object
#  1   Gender               216400 non-null  object
#  2   Age                  216400 non-null  int64
#  3   Region_Code          216400 non-null  object
#  4   Occupation           216400 non-null  object
#  5   Channel_Code         216400 non-null  object
#  6   Vintage              216400 non-null  int64
#  7   Credit_Product       216400 non-null  object
#  8   Avg_Account_Balance  216400 non-null  int64
#  9   Is_Active            216400 non-null  object
#  10  Is_Lead              216400 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 19.8+ MB

# %%
df['Is_Lead'].value_counts()
# Out:
# 0    183087
# 1     33313
# Name: Is_Lead, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      115919
# Female    100481
# Name: Gender, dtype: int64

# %%
df['Region_Code'].value_counts()
# Out:
# RG268    30313
# RG283    24663
# RG254    24100
# RG284    16354
# RG277    11315
# RG280    11277
# RG270     7249
# RG261     7054
# RG269     6988
# RG257     5529
# RG282     5254
# RG251     5235
# RG274     4905
# RG272     4655
# RG281     4533
# RG252     4056
# RG273     3932
# RG279     3556
# RG263     3315
# RG275     2999
# RG260     2803
# RG256     2661
# RG264     2626
# RG276     2356
# RG259     2349
# RG250     2323
# RG255     1801
# RG258     1728
# RG262     1636
# RG278     1617
# RG253     1592
# RG266     1484
# RG271     1424
# RG267     1386
# RG265     1332
# Name: Region_Code, dtype: int64

# %%
df['Channel_Code'].value_counts()
# Out:
# X1    100660
# X2     55892
# X3     54995
# X4      4853
# Name: Channel_Code, dtype: int64

# %%
df['Credit_Product'].value_counts()
# Out:
# No     144357
# Yes     72043
# Name: Credit_Product, dtype: int64

# %%
df['Is_Active'].value_counts()
# Out:
# No     134866
# Yes     81534
# Name: Is_Active, dtype: int64

# %%
dummies_Gender=pd.get_dummies(df['Gender'])
dummies_Region=pd.get_dummies(df['Region_Code'])
dummies_Occupation=pd.get_dummies(df['Occupation'])
dummies_Channel=pd.get_dummies(df['Channel_Code'])
dummies_CreditProduct=pd.get_dummies(df['Credit_Product'])
dummies_IsActive=pd.get_dummies(df['Is_Active'])

# %%
dummies_Gender.info()
dummies_Region.info()
dummies_Occupation.info()
dummies_Channel.info()
dummies_CreditProduct.info()
dummies_IsActive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216400 entries, 0 to 245724
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Female  216400 non-null  uint8
#  1   Male    216400 non-null  uint8
# dtypes: uint8(2)
# memory usage: 2.1 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216400 entries, 0 to 245724
# Data columns (total 35 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   RG250   216400 non-null  uint8
#  1   RG251   216400 non-null  uint8
#  2   RG252   216400 non-null  uint8
#  3   RG253   216400 non-null  uint8
#  4   RG254   216400 non-null  uint8
#  5   RG255   216400 non-null  uint8
#  6   RG256   216400 non-null  uint8
#  7   RG257   216400 non-null  uint8
#  8   RG258   216400 non-null  uint8
#  9   RG259   216400 non-null  uint8
#  10  RG260   216400 non-null  uint8
#  11  RG261   216400 non-null  uint8
#  12  RG262   216400 non-null  uint8
#  13  RG263   216400 non-null  uint8
#  14  RG264   216400 non-null  uint8
#  15  RG265   216400 non-null  uint8
#  16  RG266   216400 non-null  uint8
#  17  RG267   216400 non-null  uint8
#  18  RG268   216400 non-null  uint8
#  19  RG269   216400 non-null  uint8
#  20  RG270   216400 non-null  uint8
#  21  RG271   216400 non-null  uint8
#  22  RG272   216400 non-null  uint8
#  23  RG273   216400 non-null  uint8
#  24  RG274   216400 non-null  uint8
#  25  RG275   216400 non-null  uint8
#  26  RG276   216400 non-null  uint8
#  27  RG277   216400 non-null  uint8
#  28  RG278   216400 non-null  uint8
#  29  RG279   216400 non-null  uint8
#  30  RG280   216400 non-null  uint8
#  31  RG281   216400 non-null  uint8
#  32  RG282   216400 non-null  uint8
#  33  RG283   216400 non-null  uint8
#  34  RG284   216400 non-null  uint8
# dtypes: uint8(35)
# memory usage: 8.9 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216400 entries, 0 to 245724
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Entrepreneur   216400 non-null  uint8
#  1   Other          216400 non-null  uint8
#  2   Salaried       216400 non-null  uint8
#  3   Self_Employed  216400 non-null  uint8
# dtypes: uint8(4)
# memory usage: 2.5 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216400 entries, 0 to 245724
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   X1      216400 non-null  uint8
#  1   X2      216400 non-null  uint8
#  2   X3      216400 non-null  uint8
#  3   X4      216400 non-null  uint8
# dtypes: uint8(4)
# memory usage: 2.5 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216400 entries, 0 to 245724
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   No      216400 non-null  uint8
#  1   Yes     216400 non-null  uint8
# dtypes: uint8(2)
# memory usage: 2.1 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216400 entries, 0 to 245724
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   No      216400 non-null  uint8
#  1   Yes     216400 non-null  uint8
# dtypes: uint8(2)
# memory usage: 2.1 MB

# %%
df['Gender_Male']=dummies_Gender['Male']
df['Gender_Female']=dummies_Gender['Female']
# Out:
# <ipython-input-14-061746551977>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender_Male']=dummies_Gender['Male']
# <ipython-input-14-061746551977>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender_Female']=dummies_Gender['Female']

# %%
dummies_Region.columns
# Out:
# Index(['RG250', 'RG251', 'RG252', 'RG253', 'RG254', 'RG255', 'RG256', 'RG257',
#        'RG258', 'RG259', 'RG260', 'RG261', 'RG262', 'RG263', 'RG264', 'RG265',
#        'RG266', 'RG267', 'RG268', 'RG269', 'RG270', 'RG271', 'RG272', 'RG273',
#        'RG274', 'RG275', 'RG276', 'RG277', 'RG278', 'RG279', 'RG280', 'RG281',
#        'RG282', 'RG283', 'RG284'],
#       dtype='object')

# %%
df[['RG250', 'RG251', 'RG252', 'RG253', 'RG254', 'RG255', 'RG256', 'RG257',
       'RG258', 'RG259', 'RG260', 'RG261', 'RG262', 'RG263', 'RG264', 'RG265',
       'RG266', 'RG267', 'RG268', 'RG269', 'RG270', 'RG271', 'RG272', 'RG273',
       'RG274', 'RG275', 'RG276', 'RG277', 'RG278', 'RG279', 'RG280', 'RG281',
       'RG282', 'RG283', 'RG284']]=dummies_Region[['RG250', 'RG251', 'RG252', 'RG253', 'RG254', 'RG255', 'RG256', 'RG257',
       'RG258', 'RG259', 'RG260', 'RG261', 'RG262', 'RG263', 'RG264', 'RG265',
       'RG266', 'RG267', 'RG268', 'RG269', 'RG270', 'RG271', 'RG272', 'RG273',
       'RG274', 'RG275', 'RG276', 'RG277', 'RG278', 'RG279', 'RG280', 'RG281',
       'RG282', 'RG283', 'RG284']]
# Out:
# C:\Users\umn3cob\Anaconda3\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df['Occupation_Entrepreneur']=dummies_Occupation['Entrepreneur']
df['Occupation_Other']=dummies_Occupation['Other']
df['Occupation_Salaried']=dummies_Occupation['Salaried']
df['Occupation_Self_Employed']=dummies_Occupation['Self_Employed']
df['Channel_X1']=dummies_Channel['X1']
df['Channel_X2']=dummies_Channel['X2']
df['Channel_X3']=dummies_Channel['X3']
df['Channel_X4']=dummies_Channel['X4']
df['CreditProduct_Yes']=dummies_CreditProduct['Yes']
df['CreditProduct_No']=dummies_CreditProduct['No']
df['IsActive_Yes']=dummies_IsActive['Yes']
df['IsActive_No']=dummies_IsActive['No']
# Out:
# <ipython-input-17-a0d64c122534>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occupation_Entrepreneur']=dummies_Occupation['Entrepreneur']
# <ipython-input-17-a0d64c122534>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occupation_Other']=dummies_Occupation['Other']
# <ipython-input-17-a0d64c122534>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occupation_Salaried']=dummies_Occupation['Salaried']
# <ipython-input-17-a0d64c122534>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occupation_Self_Employed']=dummies_Occupation['Self_Employed']
# <ipython-input-17-a0d64c122534>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Channel_X1']=dummies_Channel['X1']
# <ipython-input-17-a0d64c122534>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Channel_X2']=dummies_Channel['X2']
# <ipython-input-17-a0d64c122534>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Channel_X3']=dummies_Channel['X3']
# <ipython-input-17-a0d64c122534>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Channel_X4']=dummies_Channel['X4']
# <ipython-input-17-a0d64c122534>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CreditProduct_Yes']=dummies_CreditProduct['Yes']
# <ipython-input-17-a0d64c122534>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CreditProduct_No']=dummies_CreditProduct['No']
# <ipython-input-17-a0d64c122534>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IsActive_Yes']=dummies_IsActive['Yes']
# <ipython-input-17-a0d64c122534>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IsActive_No']=dummies_IsActive['No']

# %%
df=df.drop(['Gender','Region_Code','Occupation','Channel_Code','Credit_Product','Is_Active'],axis=1)

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Vintage', 'Avg_Account_Balance', 'Is_Lead', 'Gender_Male',
#        'Gender_Female', 'RG250', 'RG251', 'RG252', 'RG253', 'RG254', 'RG255',
#        'RG256', 'RG257', 'RG258', 'RG259', 'RG260', 'RG261', 'RG262', 'RG263',
#        'RG264', 'RG265', 'RG266', 'RG267', 'RG268', 'RG269', 'RG270', 'RG271',
#        'RG272', 'RG273', 'RG274', 'RG275', 'RG276', 'RG277', 'RG278', 'RG279',
#        'RG280', 'RG281', 'RG282', 'RG283', 'RG284', 'Occupation_Entrepreneur',
#        'Occupation_Other', 'Occupation_Salaried', 'Occupation_Self_Employed',
#        'Channel_X1', 'Channel_X2', 'Channel_X3', 'Channel_X4',
#        'CreditProduct_Yes', 'CreditProduct_No', 'IsActive_Yes', 'IsActive_No'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import math
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
sns.set()
fig, ax = plt.subplots(figsize=(60,60))         # Sample figsize in inches
sns.heatmap(df.corr(),annot=True,fmt='.1g', vmin=-1, vmax=2, center= 0, cmap= 'coolwarm',cbar=False, ax=ax)
# Out:
# <AxesSubplot:>

# %%
import xgboost as xgb
model = xgb.XGBClassifier()

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Vintage', 'Avg_Account_Balance', 'Is_Lead', 'Gender_Male',
#        'Gender_Female', 'RG250', 'RG251', 'RG252', 'RG253', 'RG254', 'RG255',
#        'RG256', 'RG257', 'RG258', 'RG259', 'RG260', 'RG261', 'RG262', 'RG263',
#        'RG264', 'RG265', 'RG266', 'RG267', 'RG268', 'RG269', 'RG270', 'RG271',
#        'RG272', 'RG273', 'RG274', 'RG275', 'RG276', 'RG277', 'RG278', 'RG279',
#        'RG280', 'RG281', 'RG282', 'RG283', 'RG284', 'Occupation_Entrepreneur',
#        'Occupation_Other', 'Occupation_Salaried', 'Occupation_Self_Employed',
#        'Channel_X1', 'Channel_X2', 'Channel_X3', 'Channel_X4',
#        'CreditProduct_Yes', 'CreditProduct_No', 'IsActive_Yes', 'IsActive_No'],
#       dtype='object')

# %%
X=df[['Age', 'Vintage', 'Avg_Account_Balance', 'RG250',
       'RG251', 'RG252', 'RG253', 'RG254', 'RG255', 'RG256', 'RG257', 'RG258',
       'RG259', 'RG260', 'RG261', 'RG262', 'RG263', 'RG264', 'RG265', 'RG266',
       'RG267', 'RG268', 'RG269', 'RG270', 'RG271', 'RG272', 'RG273', 'RG274',
       'RG275', 'RG276', 'RG277', 'RG278', 'RG279', 'RG280', 'RG281', 'RG282',
       'RG283', 'RG284', 'Occupation_Entrepreneur', 'Occupation_Other',
       'Occupation_Salaried', 'Occupation_Self_Employed', 'Channel_X1',
       'Channel_X2', 'Channel_X3', 'Channel_X4', 'CreditProduct_Yes',
       'CreditProduct_No', 'IsActive_Yes', 'IsActive_No']]
Y=df[['Is_Lead']]

# %%
model.fit(X, Y)
# Out:
# C:\Users\umn3cob\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\umn3cob\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [21:45:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
df_test=pd.read_csv('test_mSzZ8RL.csv')

# %%
df_test.info()
df_test['Credit_Product'].replace(np.nan,'Yes',inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105312 entries, 0 to 105311
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   105312 non-null  object
#  1   Gender               105312 non-null  object
#  2   Age                  105312 non-null  int64
#  3   Region_Code          105312 non-null  object
#  4   Occupation           105312 non-null  object
#  5   Channel_Code         105312 non-null  object
#  6   Vintage              105312 non-null  int64
#  7   Credit_Product       92790 non-null   object
#  8   Avg_Account_Balance  105312 non-null  int64
#  9   Is_Active            105312 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 8.0+ MB

# %%
dummies_Gender=pd.get_dummies(df_test['Gender'])
dummies_Region=pd.get_dummies(df_test['Region_Code'])
dummies_Occupation=pd.get_dummies(df_test['Occupation'])
dummies_Channel=pd.get_dummies(df_test['Channel_Code'])
dummies_CreditProduct=pd.get_dummies(df_test['Credit_Product'])
dummies_IsActive=pd.get_dummies(df_test['Is_Active'])
df_test['Gender_Male']=dummies_Gender['Male']
df_test['Gender_Female']=dummies_Gender['Female']
df_test[['RG250', 'RG251', 'RG252', 'RG253', 'RG254', 'RG255', 'RG256', 'RG257',
       'RG258', 'RG259', 'RG260', 'RG261', 'RG262', 'RG263', 'RG264', 'RG265',
       'RG266', 'RG267', 'RG268', 'RG269', 'RG270', 'RG271', 'RG272', 'RG273',
       'RG274', 'RG275', 'RG276', 'RG277', 'RG278', 'RG279', 'RG280', 'RG281',
       'RG282', 'RG283', 'RG284']]=dummies_Region[['RG250', 'RG251', 'RG252', 'RG253', 'RG254', 'RG255', 'RG256', 'RG257',
       'RG258', 'RG259', 'RG260', 'RG261', 'RG262', 'RG263', 'RG264', 'RG265',
       'RG266', 'RG267', 'RG268', 'RG269', 'RG270', 'RG271', 'RG272', 'RG273',
       'RG274', 'RG275', 'RG276', 'RG277', 'RG278', 'RG279', 'RG280', 'RG281',
       'RG282', 'RG283', 'RG284']]
df_test['Occupation_Entrepreneur']=dummies_Occupation['Entrepreneur']
df_test['Occupation_Other']=dummies_Occupation['Other']
df_test['Occupation_Salaried']=dummies_Occupation['Salaried']
df_test['Occupation_Self_Employed']=dummies_Occupation['Self_Employed']
df_test['Channel_X1']=dummies_Channel['X1']
df_test['Channel_X2']=dummies_Channel['X2']
df_test['Channel_X3']=dummies_Channel['X3']
df_test['Channel_X4']=dummies_Channel['X4']
df_test['CreditProduct_Yes']=dummies_CreditProduct['Yes']
df_test['CreditProduct_No']=dummies_CreditProduct['No']
df_test['IsActive_Yes']=dummies_IsActive['Yes']
df_test['IsActive_No']=dummies_IsActive['No']

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105312 entries, 0 to 105311
# Data columns (total 59 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        105312 non-null  object
#  1   Gender                    105312 non-null  object
#  2   Age                       105312 non-null  int64
#  3   Region_Code               105312 non-null  object
#  4   Occupation                105312 non-null  object
#  5   Channel_Code              105312 non-null  object
#  6   Vintage                   105312 non-null  int64
#  7   Credit_Product            105312 non-null  object
#  8   Avg_Account_Balance       105312 non-null  int64
#  9   Is_Active                 105312 non-null  object
#  10  Gender_Male               105312 non-null  uint8
#  11  Gender_Female             105312 non-null  uint8
#  12  RG250                     105312 non-null  uint8
#  13  RG251                     105312 non-null  uint8
#  14  RG252                     105312 non-null  uint8
#  15  RG253                     105312 non-null  uint8
#  16  RG254                     105312 non-null  uint8
#  17  RG255                     105312 non-null  uint8
#  18  RG256                     105312 non-null  uint8
#  19  RG257                     105312 non-null  uint8
#  20  RG258                     105312 non-null  uint8
#  21  RG259                     105312 non-null  uint8
#  22  RG260                     105312 non-null  uint8
#  23  RG261                     105312 non-null  uint8
#  24  RG262                     105312 non-null  uint8
#  25  RG263                     105312 non-null  uint8
#  26  RG264                     105312 non-null  uint8
#  27  RG265                     105312 non-null  uint8
#  28  RG266                     105312 non-null  uint8
#  29  RG267                     105312 non-null  uint8
#  30  RG268                     105312 non-null  uint8
#  31  RG269                     105312 non-null  uint8
#  32  RG270                     105312 non-null  uint8
#  33  RG271                     105312 non-null  uint8
#  34  RG272                     105312 non-null  uint8
#  35  RG273                     105312 non-null  uint8
#  36  RG274                     105312 non-null  uint8
#  37  RG275                     105312 non-null  uint8
#  38  RG276                     105312 non-null  uint8
#  39  RG277                     105312 non-null  uint8
#  40  RG278                     105312 non-null  uint8
#  41  RG279                     105312 non-null  uint8
#  42  RG280                     105312 non-null  uint8
#  43  RG281                     105312 non-null  uint8
#  44  RG282                     105312 non-null  uint8
#  45  RG283                     105312 non-null  uint8
#  46  RG284                     105312 non-null  uint8
#  47  Occupation_Entrepreneur   105312 non-null  uint8
#  48  Occupation_Other          105312 non-null  uint8
#  49  Occupation_Salaried       105312 non-null  uint8
#  50  Occupation_Self_Employed  105312 non-null  uint8
#  51  Channel_X1                105312 non-null  uint8
#  52  Channel_X2                105312 non-null  uint8
#  53  Channel_X3                105312 non-null  uint8
#  54  Channel_X4                105312 non-null  uint8
#  55  CreditProduct_Yes         105312 non-null  uint8
#  56  CreditProduct_No          105312 non-null  uint8
#  57  IsActive_Yes              105312 non-null  uint8
#  58  IsActive_No               105312 non-null  uint8
# dtypes: int64(3), object(7), uint8(49)
# memory usage: 13.0+ MB

# %%
df_test=df_test.drop(['Gender','Region_Code','Occupation','Channel_Code','Credit_Product','Is_Active'],axis=1)

# %%
test_features=df_test[[ 'Age', 'Vintage', 'Avg_Account_Balance', 'RG250',
       'RG251', 'RG252', 'RG253', 'RG254', 'RG255', 'RG256', 'RG257', 'RG258',
       'RG259', 'RG260', 'RG261', 'RG262', 'RG263', 'RG264', 'RG265', 'RG266',
       'RG267', 'RG268', 'RG269', 'RG270', 'RG271', 'RG272', 'RG273', 'RG274',
       'RG275', 'RG276', 'RG277', 'RG278', 'RG279', 'RG280', 'RG281', 'RG282',
       'RG283', 'RG284', 'Occupation_Entrepreneur', 'Occupation_Other',
       'Occupation_Salaried', 'Occupation_Self_Employed', 'Channel_X1',
       'Channel_X2', 'Channel_X3', 'Channel_X4', 'CreditProduct_Yes',
       'CreditProduct_No', 'IsActive_Yes', 'IsActive_No']]
df_test['Is_Lead']=model.predict(test_features)
# Out:
# C:\Users\umn3cob\Anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
df_output=pd.DataFrame()
df_output[['ID','Is_Lead']]=df_test[['ID','Is_Lead']]

# %%
df_output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105312 entries, 0 to 105311
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       105312 non-null  object
#  1   Is_Lead  105312 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.6+ MB

# %%
df_output.to_csv('Output.csv')

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X,Y)
df_test['Is_Lead_Random']=model.predict(test_features)
df_output_random=pd.DataFrame()
df_output_random[['ID','Is_Lead']]=df_test[['ID','Is_Lead_Random']]
# Out:
# <ipython-input-34-61d8b1be8b1e>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X,Y)
# C:\Users\umn3cob\Anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
df_output_random.to_csv('Output_Random.csv')

# %% [raw]
# #Number of trees in random forest
# n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num =10)]
# # Number of features to consider at every split
# max_features = ['auto', 'sqrt']
# # Maximum number of levels in tree
# max_depth = [int(x) for x in np.linspace(10, 110, num = 10)]
# max_depth.append(None)
# # Minimum number of samples required to split a node
# min_samples_split = [2, 5, 10]
# # Minimum number of samples required at each leaf node
# min_samples_leaf = [1, 2, 4]
# # Method of selecting samples for training each tree
# bootstrap = [True, False]
# # Create the random grid
# random_grid = {'n_estimators': n_estimators,
#                'max_features': max_features,
#                'max_depth': max_depth,
#                'min_samples_split': min_samples_split,
#                'min_samples_leaf': min_samples_leaf,
#                'bootstrap': bootstrap}
# print(random_grid)
# # Use the random grid to search for best hyperparameters
# # First create the base model to tune
# rf = RandomForestClassifier()
# # Random search of parameters, using 3 fold cross validation,
# # search across 100 different combinations, and use all available cores
# rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# # Fit the random search model
# rf_random.fit(X, Y)
# rf_random.best_params_

# %%
rf_tuned= RandomForestClassifier(n_estimators= 200,
 min_samples_split= 2,
 min_samples_leaf= 4,
 max_depth=21,
 bootstrap=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X)
rf_tuned.fit(X_train_scaled, np.ravel(Y))

X_test_scaled = scaler.fit_transform(test_features)
df_test['Is_Lead_rf_tune']=rf_tuned.predict(X_test_scaled)
df_output1=pd.DataFrame()
df_output1[['ID','Is_Lead']]=df_test[['ID','Is_Lead_rf_tune']]
df_output1.to_csv('Output_rf_tune_scaled.csv',index=False)

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from matplotlib import pyplot
# feature selection
def select_features(X_train, y_train, X_test):
	# configure to select all features
	fs = SelectKBest(score_func=f_regression, k='all')
	# learn relationship from training data
	fs.fit(X_train, y_train)
	# transform train input data
	X_train_fs = fs.transform(X_train)
	# transform test input data
	X_test_fs = fs.transform(X_test)
	return X_train_fs, X_test_fs, fs
 
# load the dataset
#X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1, random_state=1)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_train_scaled, np.ravel(Y), test_size=0.20, random_state=1)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)
col=X.columns
# what are scores for the features
for i in range(len(fs.scores_)):
	print('Feature %s: %f' % (col[i], fs.scores_[i]))
# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# Feature Age: 5488.540653
# Feature Vintage: 9198.399828
# Feature Avg_Account_Balance: 306.044191
# Feature RG250: 34.637345
# Feature RG251: 0.071904
# Feature RG252: 90.088606
# Feature RG253: 0.005470
# Feature RG254: 34.595249
# Feature RG255: 0.955653
# Feature RG256: 79.903476
# Feature RG257: 29.789003
# Feature RG258: 2.543287
# Feature RG259: 13.248867
# Feature RG260: 19.132536
# Feature RG261: 94.710763
# Feature RG262: 12.370279
# Feature RG263: 0.957058
# Feature RG264: 61.001654
# Feature RG265: 0.541592
# Feature RG266: 21.866904
# Feature RG267: 27.604530
# Feature RG268: 399.773010
# Feature RG269: 5.474290
# Feature RG270: 154.594657
# Feature RG271: 13.230768
# Feature RG272: 8.647649
# Feature RG273: 0.368912
# Feature RG274: 61.547051
# Feature RG275: 34.091540
# Feature RG276: 7.240500
# Feature RG277: 1.664589
# Feature RG278: 2.441941
# Feature RG279: 0.459917
# Feature RG280: 0.016456
# Feature RG281: 10.225518
# Feature RG282: 35.915027
# Feature RG283: 376.233576
# Feature RG284: 244.166664
# Feature Occupation_Entrepreneur: 1598.907626
# Feature Occupation_Other: 0.581032
# Feature Occupation_Salaried: 1075.845295
# Feature Occupation_Self_Employed: 540.750890
# Feature Channel_X1: 8841.605476
# Feature Channel_X2: 1815.891431
# Feature Channel_X3: 3956.889580
# Feature Channel_X4: 0.418689
# Feature CreditProduct_Yes: 19094.921604
# Feature CreditProduct_No: 19094.921604
# Feature IsActive_Yes: 831.939818
# Feature IsActive_No: 831.939818

# %%
X1=df[['Age', 'Vintage', 'Avg_Account_Balance', 'RG250',
        'RG252', 'RG254', 'RG256',
       'RG261',  'RG264',  'RG268', 'RG270', 'RG274',
       'RG283', 'RG284', 'Occupation_Entrepreneur', 'Occupation_Other',
       'Occupation_Salaried', 'Occupation_Self_Employed', 'Channel_X1',
       'Channel_X2', 'Channel_X3', 'CreditProduct_Yes',
       'CreditProduct_No', 'IsActive_Yes', 'IsActive_No']]
Y1=df['Is_Lead']

# %%
import seaborn as sns 
sns.set()
sns.distplot(X1['Avg_Account_Balance'])
# Out:
# C:\Users\umn3cob\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Avg_Account_Balance', ylabel='Density'>

# %%
X1['Avg_Account_Balance'] = np.log(X1['Avg_Account_Balance'])
sns.distplot(X1['Avg_Account_Balance'])
plt.show()
# Out:
# <ipython-input-41-f20e9df54796>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1['Avg_Account_Balance'] = np.log(X1['Avg_Account_Balance'])
# C:\Users\umn3cob\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
test_features2=df_test[[ 'Age', 'Vintage', 'Avg_Account_Balance', 'RG250',
        'RG252', 'RG254', 'RG256',
       'RG261',  'RG264',  'RG268', 'RG270', 'RG274',
       'RG283', 'RG284', 'Occupation_Entrepreneur', 'Occupation_Other',
       'Occupation_Salaried', 'Occupation_Self_Employed', 'Channel_X1',
       'Channel_X2', 'Channel_X3', 'CreditProduct_Yes',
       'CreditProduct_No', 'IsActive_Yes', 'IsActive_No']]
test_features2['Avg_Account_Balance']=np.log(test_features2['Avg_Account_Balance'])
# Out:
# <ipython-input-42-38c65d6aeaad>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_features2['Avg_Account_Balance']=np.log(test_features2['Avg_Account_Balance'])

# %%
rf_tuned= RandomForestClassifier(n_estimators= 200,
 min_samples_split= 2,
 min_samples_leaf= 4,
 max_depth=21,
 bootstrap=True)



from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled1 = scaler.fit_transform(X1)
rf_tuned.fit(X_train_scaled1, np.ravel(Y))

X_test_scaled2 = scaler.fit_transform(test_features2)
df_test['Is_Lead_rf_tune']=rf_tuned.predict(X_test_scaled2)
df_output1=pd.DataFrame()
df_output1[['ID','Is_Lead']]=df_test[['ID','Is_Lead_rf_tune']]
df_output1.to_csv('Output_rf_tune_scaled_FP.csv',index=False)

# %%
from imblearn.under_sampling import RandomUnderSampler 
from imblearn.over_sampling import RandomOverSampler 
def over_under_sample(X_train, y_train, Under=True, Over=True):
    """
    Input: training features and target
    Output: under/oversampled datasets
    """
    rus = RandomUnderSampler(random_state=42)
    ros = RandomOverSampler(random_state=42)

    if Under and Over:
        X_train_under, y_train_under = rus.fit_resample (X_train, y_train)
        X_train_over, y_train_over = ros.fit_resample (X_train, y_train)
        return X_train_under, y_train_under, X_train_over, y_train_over
    elif Under:
        X_train_under, y_train_under = rus.fit_resample(X_train, y_train)
        return X_train_under, y_train_under
    else:
        X_train_over, y_train_over = ros.fit_resample(X_train, y_train)
        


# Random under/over sampling
X_train_under, y_train_under, X_train_over, y_train_over = over_under_sample(X_train_scaled1, np.ravel(Y), Under=True, Over=True)

# %%
rf_tuned_under= RandomForestClassifier(n_estimators= 200,
 min_samples_split= 2,
 min_samples_leaf= 4,
 max_depth=21,
 bootstrap=True)

rf_tuned_under.fit(X_train_under,y_train_under)
test_features2['Avg_Account_Balance']=np.log(test_features2['Avg_Account_Balance'])
X_test_scaled2 = scaler.fit_transform(test_features2)
df_test['Is_Lead_rf_tune']=rf_tuned_under.predict(X_test_scaled2)
df_output1=pd.DataFrame()
df_output1[['ID','Is_Lead']]=df_test[['ID','Is_Lead_rf_tune']]
df_output1.to_csv('Output_rf_tune_scaled_FP_under.csv',index=False)
# Out:
# <ipython-input-45-dc6347179830>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_features2['Avg_Account_Balance']=np.log(test_features2['Avg_Account_Balance'])

# %%
rf_tuned_over= RandomForestClassifier(n_estimators= 200,
 min_samples_split= 2,
 min_samples_leaf= 4,
 max_depth=21,
 bootstrap=True)

rf_tuned_over.fit(X_train_over,y_train_over)

X_test_scaled2 = scaler.fit_transform(test_features2)
df_test['Is_Lead_rf_tune']=rf_tuned_over.predict(X_test_scaled2)
df_output1=pd.DataFrame()
df_output1[['ID','Is_Lead']]=df_test[['ID','Is_Lead_rf_tune']]
df_output1.to_csv('Output_rf_tune_scaled_FP_overr.csv',index=False)

# %%
model_xgb = xgb.XGBClassifier()

model_xgb.fit(X_train_under,y_train_under)

X_test_scaled2 = scaler.fit_transform(test_features2)
df_test['Is_Lead_rf_tune']=model_xgb.predict(X_test_scaled2)
df_output1=pd.DataFrame()
df_output1[['ID','Is_Lead']]=df_test[['ID','Is_Lead_rf_tune']]
df_output1.to_csv('Output_xgb_tune_scaled_FP_under.csv',index=False)
# Out:
# C:\Users\umn3cob\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:50:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\umn3cob\Anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
from catboost import CatBoostClassifier
cat_model = CatBoostClassifier(n_estimators=20000, 
                  depth= 4, 
                  learning_rate=0.023, 
                  colsample_bylevel=0.655, 
                  bagging_temperature=0.921, 
                l2_leaf_reg=10.133)
cat_model.fit(X_train_under,y_train_under)
df_test['Is_Lead_rf_tune']=cat_model.predict(X_test_scaled2)
df_output1=pd.DataFrame()
df_output1[['ID','Is_Lead']]=df_test[['ID','Is_Lead_rf_tune']]
df_output1.to_csv('Output_cat_under.csv',index=False)
# Out:
# 0:	learn: 0.6860134	total: 88.2ms	remaining: 29m 24s
# 1:	learn: 0.6799499	total: 104ms	remaining: 17m 22s
